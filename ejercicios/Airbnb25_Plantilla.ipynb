# %% [markdown]
# <a href="https://colab.research.google.com/github/OctavioSantalucia/econometria/blob/main/ejercicios/Airbnb25_Plantilla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
df=pd.read_excel('https://github.com/rpasquini/econometria/blob/main/datos/listings_26_dic_2023.xlsx?raw=True', sheet_name='listings', engine='openpyxl')

# %%
df.head()
