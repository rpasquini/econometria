# %% [markdown]
# <a href="https://colab.research.google.com/github/franciscosesto/econometria/blob/main/notebooks/4_Python_Austral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>
# <b> Python Econometría
# </h1>
#
#
# <div>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/800px-Python-logo-notext.svg.png " width="100"/>
# </div>

# %% [markdown]
# ##**🤔 ¿Qué es?**

# %% [markdown]
# Python es un lenguaje de programación de alto nivel, código abierto,
# orientado a objetos, simple y fácil de entender.
#
#
# 1.   **Alto nivel:** Un lenguaje de programación de alto nivel es aquel que ***está cerca del lenguaje humano y se aleja del lenguaje de la máquina***.
# 2.   **Código abierto:** Su ***código fuente está disponible*** para ser utilizado, modificado y distribuido de manera gratuita por cualquier persona.
# 3.    **Orientado a objetos:** Se basa en el ***concepto de objetos y clases***. Los objetos tienen características y comportamientos, y se relacionan entre sí para formar un programa.

# %% [markdown]
# 🔥
# Para programar con comodidad se suele instalar un "IDE" o editor de texto.
# Por ahora trabajaremos con un entorno de Google para enfocarnos solo en la
# programación, este entorno se llama Colab. 🔥

# %% [markdown]
# ## 🧲 **Estructuras de control de flujo**

# %% [markdown]
# ### ➖ Flujo

# %% [markdown]
# El flujo es una forma de entender la sucesión de las instrucciones de un programa, estas instrucciones se ejecutan una después de otras de forma ordenada y suelen tener el objetivo final de manipular información.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sin embargo, para manipular datos no es suficiente con realizar cálculos o resolver expresiones, **necesitamos que de alguna forma nuestro programa pueda elegir, que sepa cómo actuar en función de determinadas situaciones, o incluso repetir una tarea si es necesario**. Para estas situaciones, existen las sentencias de control de flujo.

# %% [markdown]
# ### ➖ Sentencias de control

# %% [markdown]
# Se dividen en dos tipos, las de control condicional y las de control iterativo. (A las siguientes imágenes se le denomina diagrama de flujo)
# -	**Condicionales:** para elegir entre distintas posibilidades.
# -	**Iterativas:** Para repetir un bloque de instrucciones.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ➖ IF Condicional

# %% [markdown]
# **Las sentencias de control condicionales son aquellas que nos permiten evaluar si una o más condiciones se cumplen, para decir qué acción vamos a ejecutar.** La evaluación de condiciones sólo puede arrojar 1 de 2 resultados: True o False (verdadero o falso).
#
# Para describir la evaluación a realizar sobre una condición, se utilizan los operadores relacionales (==, !=, >, <, etc). Y, para evaluar más de una condición simultáneamente se utilizan los operadores lógicos (not, and, or).

# %% [markdown]
# *Sintaxis del if condicional*

# %% [markdown]
# ```python
# if condición1:
#     bloque código
# elif condición2:
#     bloque código
#     …
# else:
#     bloque código
# ```

# %% [markdown]
# Evalúa la expresión lógica **condición1** y ejecuta el primer bloque de código si es **True**; si no, evalúa la siguientes condiciones **elif** hasta llegar a la primera que es **True** y ejecuta el bloque de código asociado. Si ninguna condición es **True** ejecuta el bloque de código después de **else**:.

# %%
#Ejemplo If
persona1= "Ramona"
persona2= "Clara"
persona3= "Susana"

if persona1=="Susana": #Uso un operador lógico (==) para comparar si se es igual a Susana el nombre
    print("Hola Susana te estamos llamando queremos jugar")
    print("Susana es la persona 1")
elif persona2=="Susana": 
    print("Hola Susana te estamos llamando queremos jugar")
    print("Susana es la persona 2")
elif persona3=="Susana": 
    print("Hola Susana te estamos llamando queremos jugar")
    print("Susana es la persona 3")
else:
    print("Susana no está")
# Out:
# Hola Susana te estamos llamando queremos jugar
# Susana es la persona 3

# %% [markdown]
# 🔥 En Python definimos un bloque de código después de una sentencia de control escribiendo dos puntitos : y todo el bloque que se ejecutará debe de estar indentado. **Luego de los dos puntitos hay que usar al menos 1 espacio pero se acostumbra a usar 4 espacios**  🔥

# %%
#Bloque no indentado
if 5>4:
print("es mayor a 4")

#Nos devuelve un error
# Out:
#   File "<ipython-input-9-06f649c1fd3f>", line 3
#     print("es mayor a 4")
#     ^
# IndentationError: expected an indented block

# %%
#Bloque indentado con 4 espacios
if 5>4:
    print("es mayor a 4")
# Out:
# es mayor a 4

# %% [markdown]
# ### ➖ While Iterativo

# %% [markdown]
# **Se basa en repetir un bloque de código a partir de evaluar una condición lógica, siempre que ésta sea True** (al igual que la sentencia if).
#
# Nosotros como programadores debemos decidir el momento en que la condición cambie a False para hacer que el While finalice su ejecución y así salir de la iteración, de lo contrario estaríamos frente a un bucle infinito.

# %% [markdown]
# *Sintaxis del bucle while*

# %% [markdown]
# ```python
# while condición:
#     bloque código
# ```

# %% [markdown]
# Repite la ejecución del bloque de código mientras la expresión lógica condición sea cierta. En el caso de que siempre sea cierta el bloque se ejecutará para siempre

# %%
#Ejemplo while infinito 
while True:
    print("Es un bucle infinito")
#RECOMENDACIÓN NO EJECUTAR POR MUCHO TIEMPO

# %%
#Ejemplo while con condición
number=9
while number!=0: #Mientras que el número sea distinto a cero
    print(number) #Lo imprimo
    number = number - 1 #Le resto 1
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# 🔥 Al igual que el IF debe estar indentado con 4 espacios  🔥

# %% [markdown]
# ***Break en while***

# %% [markdown]
# La instrucción break le **proporciona la oportunidad de cerrar un bucle cuando se activa una condición externa.** Debe poner la instrucción break dentro del bloque de código bajo la instrucción de su bucle, generalmente después de una sentencia if condicional.

# %%
# Pregunta al usuario por un número hasta que introduce 0.
while True:
    num = int(input('Introduce un número: ')) #La función input pide que el usuario pase un valor escrito y ponga enter
    if num == 0:
        print("Has descubierto el número secreto")
        break
# Out:
# Introduce un número: 5
# Introduce un número: 4
# Introduce un número: 0
# Has descubierto el número secreto

# %% [markdown]
# ### ➖ For Iterativo

# %% [markdown]
# **Se utiliza para recorrer los elementos de un objeto iterable** (lista, tupla…) y ejecutar un bloque de código, o sea, tiene un número predeterminado de veces que itera.
#
# En cada paso de la iteración se tiene en cuenta a un único elemento del objeto iterable, sobre el cuál se pueden aplicar una serie de operaciones.

# %% [markdown]
# *Sintaxis del bucle for*

# %% [markdown]
# ```python
# for i in secuencia:
#     bloque código
# ```

# %% [markdown]
# Repite la ejecución del bloque de código para cada elemento de la secuencia **secuencia**, asignado dicho elemento a **i** en cada repetición.
#
# Se puede interrumpir en cualquier momento la ejecución del bloque de código con la instrucción **break** o saltar la ejecución para un determinado elemento de la secuencia con la instrucción **continue**.

# %%
#Ejemplo for simple
lista=[1, 2, 3, 4]
for value in lista:
     print(value)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# 🔥 Al igual que el IF y el While debe estar indentado con 4 espacios  🔥

# %%
#Ejemplo for cuadrado de números
lista=[1, 2, 3, 4]
for value in lista:
     print(value**2)
# Out:
# 1
# 4
# 9
# 16

# %%
#Ejemplo for con break 
lista=[1, 2, 3, 4]
for value in lista:
     if value==3:
       break #El break corta el ciclo for en el momento que se cumple la condición
     else:
       print(value)
# Out:
# 1
# 2

# %%
#Ejemplo for con continue
lista=[1, 2, 3, 4]
for value in lista:
     if value==3:
       continue  #El continue ignora el valor de value en el momento que se cumple la condición
     else:
       print(value)
# Out:
# 1
# 2
# 4

# %% [markdown]
# ***Range***

# %% [markdown]
# La función range(inicio, fin-1, paso) en Python sirve para generar una secuencia de números enteros. Se puede usar con uno, dos o tres argumentos.
#
# - Con un solo argumento, range(n) genera una secuencia de números del 0 al n-1.
# - Con dos argumentos, range(a, b) genera una secuencia de números desde a hasta b-1.
# - Con tres argumentos, range(a, b, c) genera una secuencia desde a hasta el número más cercano a b (pero menor que b) aumentando en c en cada paso.
#
#
# Es una función muy útil y se utiliza comúnmente en ciclos for para generar una secuencia de números sobre los que iterar.

# %%
#Range con un argumento
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#Range con dos argumentos
for i in range(2, 8):
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
#Range con tres argumentos
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## 🌏 Recursos

# %% [markdown]
# En el caso de que deseen ahondar más en los temás presentamos los siguientes recursos (algunos de los cuales fueron utilizados para armar este tutorial)
# - https://docs.python.org/es/3/tutorial/index.html (documentación oficial de python)
# - https://aprendeconalf.es/docencia/python/manual/ (manual de python de aprende con alf)
# - https://www.w3schools.com/python/default.asp (tutorial de w3schools)
# - https://docs.hektorprofe.net/python/
# - https://www.geeksforgeeks.org/python-programming-language/?ref=ghm
# - https://www.freecodecamp.org/learn/data-analysis-with-python/

# %% [markdown]
# ## 📎 Autores
# El presente tutorial fue elaborado por
# - Pasquini Ricardo
# - Sesto Francisco
